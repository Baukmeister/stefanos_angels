# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns; sns.set()
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
dataCleveland = pd.read_csv("processed.cleveland.csv", sep = "\t", lineterminator='\r')
dataHungarian = pd.read_csv("processed.Hungarian.csv", sep = "\t", lineterminator='\r')
dataSwitzerland = pd.read_csv("processed.switzerland.csv")
dataVA = pd.read_csv("processed.va.csv")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\GTSA-I~1\AppData\Local\Temp/ipykernel_11244/2792368918.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # COLUMN DESCRIPTION:
#
# - int age - age in years
# - int sex - sex (1 = male; 0 = female)
# - int cp - chest pain type (1 = typical angina; 2 = atypical angina; 3 = non-anginal pain; 4 = asymptomatic)
# - int trestbps - resting blood pressure (in mm Hg on admission to the hospital)
# - int chol - serum cholestoral in mg/dl
# - int fbs - fasting blood sugar > 120 mg/dl (1 = true; 0 = false)
# - int restecg - resting electrocardiographic results (0 = normal; 1 = having ST-T; 2 = hypertrophy)
# - int thalach - maximum heart rate achieved
# - int exang - exercise induced angina (1 = yes; 0 = no)
# - float oldpeak - ST depression induced by exercise relative to rest
# - int slope - the slope of the peak exercise ST segment (1 = upsloping; 2 = flat; 3 = downsloping)
# - int ca - number of major vessels (0-3) colored by flourosopy
# - int thal - 3 = normal; 6 = fixed defect; 7 = reversable defect
# - int num - the predicted attribute - diagnosis of heart disease (angiographic disease status) (Value 0 = < 50% diameter narrowing; Value 1 = > 50% diameter narrowing)
#
# To summarize:
#
# - numerical are: age, trestbps, chol, thalac, oldpeak
# - categorical are: sex, cp, fbs, restecg, exang, slope, thal, class
# - our class/target is the column class

# %%
dataHungarian.head(10);
dataSwitzerland.head(10);
dataVA.head(10);
dataCleveland.head(10)
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0  145.0     233.0  1.0  2.0      150.0    0.0    2.3
# 1  67.0  1.0  4.0  160.0     286.0  0.0  2.0      108.0    1.0    1.5
# 2  67.0  1.0  4.0  120.0     229.0  0.0  2.0      129.0    1.0    2.6
# 3  37.0  1.0  3.0  130.0     250.0  0.0  0.0      187.0    0.0    3.5
# 4  41.0  0.0  2.0  130.0     204.0  0.0  2.0      172.0    0.0    1.4
# 5  56.0  1.0  2.0  120.0     236.0  0.0  0.0      178.0    0.0    0.8
# 6  62.0  0.0  4.0  140.0     268.0  0.0  2.0      160.0    0.0    3.6
# 7  57.0  0.0  4.0  120.0     354.0  0.0  0.0      163.0    1.0    0.6
# 8  63.0  1.0  4.0  130.0     254.0  0.0  2.0      147.0    0.0    1.4
# 9  53.0  1.0  4.0  140.0     203.0  1.0  2.0      155.0    1.0    3.1
#
#    slope   ca thal  num
# 0  3.0    0.0  6.0  0
# 1  2.0    3.0  3.0  2
# 2  2.0    2.0  7.0  1
# 3  3.0    0.0  3.0  0
# 4  1.0    0.0  3.0  0
# 5  1.0    0.0  3.0  0
# 6  3.0    2.0  3.0  3
# 7  1.0    0.0  3.0  0
# 8  2.0    1.0  7.0  2
# 9  3.0    0.0  7.0  1

# %%
dataCleveland.dtypes;

dataHungarian.dtypes;

dataSwitzerland.dtypes;

dataVA.dtypes;

# %%
dataCleveland.eq("?").sum();

dataHungarian.eq("?").sum();

dataSwitzerland.eq("?").sum();

dataVA.eq("?").sum();

# %% [markdown]
# # Playaround with DataCleveland since it contains least ?
# - drop ? and check that we lost 6 rows
# - Correct datatypes
# - Heatmap
# - PCA
# - classification
#     drop class label in a new frame
#     normalize data

# %%
#Drop rows with ?
newCleveland = dataCleveland.copy()
newCleveland = newCleveland[newCleveland.ca != "?"]
newCleveland = newCleveland[newCleveland.thal != "?"]

# %%
newCleveland["num"].replace({2: 1, 3: 1, 4: 1}, inplace = True)

# %%
"""
Groupby: allows you to group together rows based on a column and perform an aggregate function on them. 
After groupby, specify a summarization function!

To plot: 
Call unstack, that pivots the grouped dataframe back, and just call plot with kind equals to bar!

stacked: The bars for the different class labels will be put one top of each other, instead of next to each other. 
Convert it to False if you want to see the difference
"""

ylabels = ['negative', 'positive']
labels = ("female", "male")

positions = (0, 1)

s_x = newCleveland.groupby("sex")['num'].value_counts()
s_x.unstack().plot(kind='bar', stacked= True)

plt.legend(labels=ylabels)
plt.xticks(positions, labels)
plt.show()

# %%
"""
Same procedure: 

"""

by_age= newCleveland.groupby(["age"])['num'].value_counts()
by_age.unstack().plot(kind='bar', stacked=True)
plt.legend(labels=ylabels)
plt.show()

# %%
#Data visualisation 

fig, ax = plt.subplots(1, 4)

plt.tight_layout()
ax[0].boxplot(newCleveland['trestbps'])
ax[0].set_title("trestbps")

ax[1].set_title('chol')
ax[1].boxplot(newCleveland["chol"])

ax[2].set_title('thalach')
ax[2].boxplot(newCleveland["thalach"])

ax[3].set_title('oldpeak')
ax[3].boxplot(newCleveland["oldpeak"])
plt.show()

# %%
"""
Pairplot from seaborn:  investigates pairwise relationships.

Make a list of the numerical values, and in hue pass the class!


On the diagonal you see the distribution of these diffeent numerical variables

"""
sns.pairplot(newCleveland[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'num']], hue='num', size=2.5)
# Out:
# C:\Users\GTSA - Infinity\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Correlation heatmap
#Using Pearson Correlation

plt.figure(figsize=(12,10))

#Computes pairwise correlation of columns, excluding NA/null value. returns 
cor = newCleveland.corr()

#Plots rectangular data as a color-encoded matrix. note that we are using seaborn. The parameter data needs to be rectangular dataset of pairwise correlations
sns.heatmap(data=cor, annot=True, cmap=plt.cm.Reds);

plt.show()

# %% [markdown]
# # Classification

# %%
X = newCleveland.drop("num", axis = 1)
y = newCleveland.num

# %%
#Normalization
x = X.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
newClevelandNorm = pd.DataFrame(x_scaled, columns=X.columns)

# %%
#Correcting ints
newClevelandNorm.sex = newClevelandNorm.sex.astype(int)
newClevelandNorm.fbs = newClevelandNorm.fbs.astype(int)
newClevelandNorm.exang = newClevelandNorm.exang.astype(int)
newClevelandNorm.ca = newClevelandNorm.ca.astype(int)
newClevelandNorm.head()
# Out:
#         age  sex        cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.708333  1    0.000000  0.481132  0.244292  1    1.0      0.603053  0
# 1  0.791667  1    1.000000  0.622642  0.365297  0    1.0      0.282443  1
# 2  0.791667  1    1.000000  0.245283  0.235160  0    1.0      0.442748  1
# 3  0.166667  1    0.666667  0.339623  0.283105  0    0.0      0.885496  0
# 4  0.250000  0    0.333333  0.339623  0.178082  0    1.0      0.770992  0
#
#     oldpeak  slope  ca  thal
# 0  0.370968  1.0    0   0.75
# 1  0.241935  0.5    1   0.00
# 2  0.419355  0.5    0   1.00
# 3  0.564516  1.0    0   0.00
# 4  0.225806  0.0    0   0.00

# %% [markdown]
# ## Designate your attributes (X) and class labels (y)

# %%
X_train, X_test, y_train, y_test = train_test_split(newClevelandNorm, y, test_size=0.3, random_state=0)
clf = tree.DecisionTreeClassifier(random_state=0, max_depth=10, criterion="entropy")
clf = clf.fit(X_train, y_train)

# %% [markdown]
# ## Building and Evaluating Decision Trees

# %%
tree.plot_tree(clf.fit(X_train, y_train))
# Out:
# [Text(197.4796875, 207.55636363636364, 'X[2] <= 0.833\nentropy = 0.995\nsamples = 207\nvalue = [112, 95]'),
#  Text(102.009375, 187.7890909090909, 'X[0] <= 0.573\nentropy = 0.695\nsamples = 107\nvalue = [87, 20]'),
#  Text(41.85, 168.0218181818182, 'X[12] <= 0.875\nentropy = 0.387\nsamples = 66\nvalue = [61, 5]'),
#  Text(20.925, 148.25454545454545, 'X[9] <= 0.573\nentropy = 0.139\nsamples = 51\nvalue = [50, 1]'),
#  Text(10.4625, 128.48727272727274, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(31.387500000000003, 128.48727272727274, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(62.775000000000006, 148.25454545454545, 'X[4] <= 0.233\nentropy = 0.837\nsamples = 15\nvalue = [11, 4]'),
#  Text(52.3125, 128.48727272727274, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(73.2375, 128.48727272727274, 'X[5] <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(62.775000000000006, 108.72, 'X[10] <= 0.25\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(41.85, 88.95272727272729, 'X[3] <= 0.726\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(31.387500000000003, 69.18545454545455, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(52.3125, 69.18545454545455, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(83.7, 88.95272727272729, 'X[9] <= 0.081\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(73.2375, 69.18545454545455, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(94.16250000000001, 69.18545454545455, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(83.7, 108.72, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(162.16875000000002, 168.0218181818182, 'X[1] <= 0.5\nentropy = 0.947\nsamples = 41\nvalue = [26, 15]'),
#  Text(136.01250000000002, 148.25454545454545, 'X[0] <= 0.698\nentropy = 0.485\nsamples = 19\nvalue = [17, 2]'),
#  Text(125.55000000000001, 128.48727272727274, 'X[7] <= 0.649\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(115.0875, 108.72, 'X[4] <= 0.216\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(104.625, 88.95272727272729, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(125.55000000000001, 88.95272727272729, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(136.01250000000002, 108.72, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(146.475, 128.48727272727274, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(188.32500000000002, 148.25454545454545, 'X[4] <= 0.271\nentropy = 0.976\nsamples = 22\nvalue = [9, 13]'),
#  Text(167.4, 128.48727272727274, 'X[9] <= 0.395\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(156.9375, 108.72, 'X[4] <= 0.243\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(146.475, 88.95272727272729, 'X[7] <= 0.527\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(136.01250000000002, 69.18545454545455, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(156.9375, 69.18545454545455, 'X[3] <= 0.538\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(146.475, 49.418181818181836, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(167.4, 49.418181818181836, 'X[3] <= 0.642\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(156.9375, 29.650909090909096, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(177.8625, 29.650909090909096, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(167.4, 88.95272727272729, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(177.8625, 108.72, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(209.25, 128.48727272727274, 'X[3] <= 0.259\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]'),
#  Text(198.7875, 108.72, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(219.7125, 108.72, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(292.95, 187.7890909090909, 'X[9] <= 0.113\nentropy = 0.811\nsamples = 100\nvalue = [25, 75]'),
#  Text(272.02500000000003, 168.0218181818182, 'X[4] <= 0.325\nentropy = 1.0\nsamples = 36\nvalue = [18, 18]'),
#  Text(261.5625, 148.25454545454545, 'X[9] <= 0.04\nentropy = 0.981\nsamples = 31\nvalue = [18, 13]'),
#  Text(251.10000000000002, 128.48727272727274, 'X[4] <= 0.18\nentropy = 1.0\nsamples = 26\nvalue = [13, 13]'),
#  Text(240.63750000000002, 108.72, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(261.5625, 108.72, 'X[3] <= 0.5\nentropy = 0.976\nsamples = 22\nvalue = [13, 9]'),
#  Text(251.10000000000002, 88.95272727272729, 'X[7] <= 0.721\nentropy = 0.934\nsamples = 20\nvalue = [13, 7]'),
#  Text(240.63750000000002, 69.18545454545455, 'X[0] <= 0.75\nentropy = 0.997\nsamples = 15\nvalue = [8, 7]'),
#  Text(230.175, 49.418181818181836, 'X[4] <= 0.233\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(219.7125, 29.650909090909096, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(240.63750000000002, 29.650909090909096, 'X[1] <= 0.5\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]'),
#  Text(230.175, 9.883636363636384, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(251.10000000000002, 9.883636363636384, 'entropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(251.10000000000002, 49.418181818181836, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(261.5625, 69.18545454545455, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(272.02500000000003, 88.95272727272729, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(272.02500000000003, 128.48727272727274, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(282.4875, 148.25454545454545, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(313.875, 168.0218181818182, 'X[12] <= 0.375\nentropy = 0.498\nsamples = 64\nvalue = [7, 57]'),
#  Text(303.4125, 148.25454545454545, 'X[0] <= 0.354\nentropy = 0.964\nsamples = 18\nvalue = [7, 11]'),
#  Text(292.95, 128.48727272727274, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(313.875, 128.48727272727274, 'X[8] <= 0.5\nentropy = 0.75\nsamples = 14\nvalue = [3, 11]'),
#  Text(303.4125, 108.72, 'X[7] <= 0.34\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(292.95, 88.95272727272729, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(313.875, 88.95272727272729, 'X[10] <= 0.75\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(303.4125, 69.18545454545455, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(324.33750000000003, 69.18545454545455, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(324.33750000000003, 108.72, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(324.33750000000003, 148.25454545454545, 'entropy = 0.0\nsamples = 46\nvalue = [0, 46]')]

# %%
ypred = clf.predict(X_test)
print(metrics.classification_report(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76        48
#            1       0.72      0.74      0.73        42
#
#     accuracy                           0.74        90
#    macro avg       0.74      0.74      0.74        90
# weighted avg       0.74      0.74      0.74        90

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(ypred, y_test)
sns.heatmap(mat.T, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show()

# %% [markdown]
# ## Building and Evaluating Random Forests

# %%
forest = RandomForestClassifier(n_estimators=10, max_depth=2, criterion='entropy', random_state=0)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=2, n_estimators=10,
#                        random_state=0)

# %%
ypredbag = forest.predict(X_test)

# %%
print(metrics.classification_report(y_test, ypredbag))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82        48
#            1       0.85      0.67      0.75        42
#
#     accuracy                           0.79        90
#    macro avg       0.80      0.78      0.78        90
# weighted avg       0.80      0.79      0.79        90

# %%
mat = confusion_matrix(y_test, ypredbag)
sns.heatmap(mat.T, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show()

# %% [markdown]
# ## Building and Evaluating Support Vector Machines

# %%
from sklearn.svm import SVC
#svm = SVC(kernel='linear')
#svm = SVC(kernel='poly', gamma='auto')
svm = SVC(kernel='rbf', gamma='auto')

svm.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
ypredsvm = svm.predict(X_test)

# %%
print(metrics.classification_report(y_test, ypredsvm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.85        48
#            1       0.89      0.74      0.81        42
#
#     accuracy                           0.83        90
#    macro avg       0.84      0.83      0.83        90
# weighted avg       0.84      0.83      0.83        90

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test, ypredsvm)
sns.heatmap(mat.T, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show()

# %% [markdown]
# # PCA

# %%
numerical = ["age", "trestbps", "chol", "thalach", "oldpeak"] #list of num features

X = newCleveland[numerical]


scaler = StandardScaler().fit(X)

data_scaled = scaler.transform(X)

data_scaled = pd.DataFrame(data_scaled, columns=numerical)
data_scaled.head(5)
# Out:
#         age  trestbps      chol   thalach   oldpeak
# 0  0.936181  0.750380 -0.276443  0.017494  1.068965
# 1  1.378929  1.596266  0.744555 -1.816334  0.381773
# 2  1.378929 -0.659431 -0.353500 -0.899420  1.326662
# 3 -1.941680 -0.095506  0.051047  1.633010  2.099753
# 4 -1.498933 -0.095506 -0.835103  0.978071  0.295874

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(data_scaled)

# %%
data_scaled.shape
x_pca.shape
# Out:
# (297, 2)

# %%
x_pca.shape
plt.figure(figsize=(8,6))
plt.scatter(x=x_pca[:,0], y=x_pca[:,1], c=newCleveland['num'], cmap='rainbow')
plt.xlabel('1st PC')
plt.ylabel('2nd PC')
# Out:
# Text(0, 0.5, '2nd PC')

# %%
pca.explained_variance_ratio_
# Out:
# array([0.35937581, 0.21941782])

# %%
pca.components_
df_comp = pd.DataFrame(pca.components_,  columns=numerical)
df_comp
# Out:
#         age  trestbps      chol   thalach   oldpeak
# 0 -0.566788 -0.387830 -0.230767  0.507857 -0.466011
# 1  0.122913  0.419141  0.692872  0.469342 -0.329938

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_comp, cmap='plasma')
# Out:
# <AxesSubplot:>
